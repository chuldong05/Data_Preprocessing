# %%
from IPython.display import display, HTML
display(HTML("<style>.container { width:80% !important; }</style>"))
# Out:
# <style>.container { width:80% !important; }</style>

# %%
import requests
import json

url = "http://openAPI.seoul.go.kr:8088/6d6542544a77686436394173695a78/json/SearchSTNTimeTableByIDService/1/5/0150/1/1"
response = requests.get(url)
# 들여쓰기가 된 채로 출력
parsed_data = json.loads(response.text)
parsed_data
# 인코딩 에러나면 쓰는 코드
# print(json.dumps(parsed_data, indent=4,ensure_ascii=False))
# Out:
# {'SearchSTNTimeTableByIDService': {'list_total_count': 253,
#   'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#   'row': [{'LINE_NUM': '01호선',
#     'FR_CODE': '133',
#     'STATION_CD': '0150',
#     'STATION_NM': '서울역',
#     'TRAIN_NO': 'K1902',
#     'ARRIVETIME': '07:16:00',
#     'LEFTTIME': '00:00:00',
#     'ORIGINSTATION': '1728',
#     'DESTSTATION': '0150',
#     'SUBWAYSNAME': '천안',
#     'SUBWAYENAME': '서울역',
#     'WEEK_TAG': '1',
#     'INOUT_TAG': '1',
#     'FL_FLAG': '',
#     'DESTSTATION2': '',
#     'EXPRESS_YN': 'D',
#     'BRANCH_LINE': ''},
#    {'LINE_NUM': '01호선',
#     'FR_CODE': '133',
#     'STATION_CD': '0150',
#     'STATION_NM': '서울역',
#     'TRAIN_NO': 'K1904',
#     'ARRIVETIME': '08:06:30',
#     'LEFTTIME': '00:00:00',
#     'ORIGINSTATION': '1408',
#     'DESTSTATION': '0150',
#     'SUBWAYSNAME': '신창',
#     'SUBWAYENAME': '서울역',
#     'WEEK_TAG': '1',
#     'INOUT_TAG': '1',
#     'FL_FLAG': '',
#     'DESTSTATION2': '',
#     'EXPRESS_YN': 'D',
#     'BRANCH_LINE': ''},
#    {'LINE_NUM': '01호선',
#     'FR_CODE': '133',
#     'STATION_CD': '0150',
#     'STATION_NM': '서울역',
#     'TRAIN_NO': 'K802',
#     'ARRIVETIME': '05:19:30',
#     'LEFTTIME': '05:20:00',
#     'ORIGINSTATION': '1701',
#     'DESTSTATION': '1915',
#     'SUBWAYSNAME': '구로',
#     'SUBWAYENAME': '동두천',
#     'WEEK_TAG': '1',
#     'INOUT_TAG': '1',
#     'FL_FLAG': '',
#     'DESTSTATION2': '',
#     'EXPRESS_YN': 'G',
#     'BRANCH_LINE': ''},
#    {'LINE_NUM': '01호선',
#     'FR_CODE': '133',
#     'STATION_CD': '0150',
#     'STATION_NM': '서울역',
#     'TRAIN_NO': 'S902',
#     'ARRIVETIME': '00:00:00',
#     'LEFTTIME': '05:24:00',
#     'ORIGINSTATION': '0150',
#     'DESTSTATION': '1906',
#     'SUBWAYSNAME': '서울역',
#     'SUBWAYENAME': '의정부',
#     'WEEK_TAG': '1',
#     'INOUT_TAG': '1',
#     'FL_FLAG': '',
#     'DESTSTATION2': '',
#     'EXPRESS_YN': 'G',
#     'BRANCH_LINE': ''},
#    {'LINE_NUM': '01호선',
#     'FR_CODE': '133',
#     'STATION_CD': '0150',
#     'STATION_NM': '서울역',
#     'TRAIN_NO': 'K804',
#     'ARRIVETIME': '05:29:30',
#     'LEFTTIME': '05:30:00',
#     'ORIGINSTATION': '1701',
#     'DESTSTATION': '0158',
#     'SUBWAYSNAME': '구로',
#     'SUBWAYENAME': '청량리',
#     'WEEK_TAG': '1',
#     'INOUT_TAG': '1',
#     'FL_FLAG': '',
#     'DESTSTATION2': '',
#     'EXPRESS_YN': 'G',
#     'BRANCH_LINE': ''}]}}

# %%
parsed_data['SearchSTNTimeTableByIDService']
# Out:
# {'list_total_count': 253,
#  'RESULT': {'CODE': 'INFO-000', 'MESSAGE': '정상 처리되었습니다'},
#  'row': [{'LINE_NUM': '01호선',
#    'FR_CODE': '133',
#    'STATION_CD': '0150',
#    'STATION_NM': '서울역',
#    'TRAIN_NO': 'K1902',
#    'ARRIVETIME': '07:16:00',
#    'LEFTTIME': '00:00:00',
#    'ORIGINSTATION': '1728',
#    'DESTSTATION': '0150',
#    'SUBWAYSNAME': '천안',
#    'SUBWAYENAME': '서울역',
#    'WEEK_TAG': '1',
#    'INOUT_TAG': '1',
#    'FL_FLAG': '',
#    'DESTSTATION2': '',
#    'EXPRESS_YN': 'D',
#    'BRANCH_LINE': ''},
#   {'LINE_NUM': '01호선',
#    'FR_CODE': '133',
#    'STATION_CD': '0150',
#    'STATION_NM': '서울역',
#    'TRAIN_NO': 'K1904',
#    'ARRIVETIME': '08:06:30',
#    'LEFTTIME': '00:00:00',
#    'ORIGINSTATION': '1408',
#    'DESTSTATION': '0150',
#    'SUBWAYSNAME': '신창',
#    'SUBWAYENAME': '서울역',
#    'WEEK_TAG': '1',
#    'INOUT_TAG': '1',
#    'FL_FLAG': '',
#    'DESTSTATION2': '',
#    'EXPRESS_YN': 'D',
#    'BRANCH_LINE': ''},
#   {'LINE_NUM': '01호선',
#    'FR_CODE': '133',
#    'STATION_CD': '0150',
#    'STATION_NM': '서울역',
#    'TRAIN_NO': 'K802',
#    'ARRIVETIME': '05:19:30',
#    'LEFTTIME': '05:20:00',
#    'ORIGINSTATION': '1701',
#    'DESTSTATION': '1915',
#    'SUBWAYSNAME': '구로',
#    'SUBWAYENAME': '동두천',
#    'WEEK_TAG': '1',
#    'INOUT_TAG': '1',
#    'FL_FLAG': '',
#    'DESTSTATION2': '',
#    'EXPRESS_YN': 'G',
#    'BRANCH_LINE': ''},
#   {'LINE_NUM': '01호선',
#    'FR_CODE': '133',
#    'STATION_CD': '0150',
#    'STATION_NM': '서울역',
#    'TRAIN_NO': 'S902',
#    'ARRIVETIME': '00:00:00',
#    'LEFTTIME': '05:24:00',
#    'ORIGINSTATION': '0150',
#    'DESTSTATION': '1906',
#    'SUBWAYSNAME': '서울역',
#    'SUBWAYENAME': '의정부',
#    'WEEK_TAG': '1',
#    'INOUT_TAG': '1',
#    'FL_FLAG': '',
#    'DESTSTATION2': '',
#    'EXPRESS_YN': 'G',
#    'BRANCH_LINE': ''},
#   {'LINE_NUM': '01호선',
#    'FR_CODE': '133',
#    'STATION_CD': '0150',
#    'STATION_NM': '서울역',
#    'TRAIN_NO': 'K804',
#    'ARRIVETIME': '05:29:30',
#    'LEFTTIME': '05:30:00',
#    'ORIGINSTATION': '1701',
#    'DESTSTATION': '0158',
#    'SUBWAYSNAME': '구로',
#    'SUBWAYENAME': '청량리',
#    'WEEK_TAG': '1',
#    'INOUT_TAG': '1',
#    'FL_FLAG': '',
#    'DESTSTATION2': '',
#    'EXPRESS_YN': 'G',
#    'BRANCH_LINE': ''}]}
