# %%
import requests
import json

url = "http://swopenapi.seoul.go.kr/api/subway/6d6542544a77686436394173695a78/json/realtimePosition/0/10/2호선"


response = requests.get(url)
# print(response.content)
# 들여쓰기가 된 채로 출력
parsed_data = json.loads(response.text)
print(json.dumps(parsed_data, indent=4,ensure_ascii=False))





# http://swopenapi.seoul.go.kr/api/subway/6d6542544a77686436394173695a78/json/realtimePosition/0/10/2%ED%98%B8%EC%84%A0
# Out:
# {
#     "errorMessage": {
#         "status": 200,
#         "code": "INFO-000",
#         "message": "정상 처리되었습니다.",
#         "link": "",
#         "developerMessage": "",
#         "total": 59
#     },
#     "realtimePositionList": [
#         {
#             "beginRow": null,
#             "endRow": null,
#             "curPage": null,
#             "pageRow": null,
#             "totalCount": 59,
#             "rowNum": 1,
#             "selectedCount": 10,
#             "subwayId": "1002",
#             "subwayNm": "2호선",
#             "statnId": "1002000208",
#             "statnNm": "왕십리",
#             "trainNo": "2114",
#             "lastRecptnDt": "20230601",
#             "recptnDt": "2023-06-01 09:48:12",
#             "updnLine": "0",
#             "statnTid": "1002000211",
#             "statnTnm": "성수종착",
#             "trainSttus": "2",
#             "directAt": "0",
#             "lstcarAt": "0"
#         },
#         {
#             "beginRow": null,
# ...
